# %% [markdown]
# $$
# \fbox{Projet Traitement du signal: Modualtion, démodulation, sous-échantillonage}
# $$
# $\underline{Julien~Louard~et~Maëlle~Thaller}$

# %% [markdown]
# I. Modulation et démodulation DSB-BC

# %%
import numpy as np
from scipy import integrate
from math import *
import matplotlib.pyplot as plt

def f1(t,theta):
    return exp(t*cos(theta))

def I(t):
    '''fonction de bessel modifiée d'ordre 0'''
    res1,_=integrate.quad(f1,0,pi,args=(t))
    return (1/pi)*res1

def signal_atransmettre(t,alpha):
    '''on choisit une fenètre de type Kaiser'''
    if abs(t)<=B/2:
        return I(pi*alpha*sqrt(1-(2*t/B)**2))/I(pi*alpha)
    else:
        return 0
    
##affichage du signal
B=7
alpha=6
T=np.linspace(-6,6,1000)
Y=[signal_atransmettre(t,alpha) for t in T]
plt.plot(T,Y)
plt.show()

##affichage de son spectre/transformée de Fourier
fcheck=np.fft.fft(signal_atransmettre)
plt.plot(np.abs(fcheck))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-6db5dd7a6f57> in <module>
#      28
#      29 ##affichage de son spectre/transformée de Fourier
# ---> 30 fcheck=np.fft.fft(signal_atransmettre)
#      31 plt.plot(np.abs(fcheck))
#      32 plt.show()
#
# <__array_function__ internals> in fft(*args, **kwargs)
#
# c:\programdata\miniconda3\lib\site-packages\numpy\fft\_pocketfft.py in fft(a, n, axis, norm)
#     179     a = asarray(a)
#     180     if n is None:
# --> 181         n = a.shape[axis]
#     182     inv_norm = 1
#     183     if norm is not None and _unitary(norm):
#
# IndexError: tuple index out of range
